# %%
import pandas as pd
import pyecharts as pye

# %%
data = pd.read_excel(r'data/1-2  中国人民解放军现役军人的民族构成.xls')
data_1 = data.sort_values('人口数', ascending=False)
data_1.head()
# Out:
#         民    族      人口数
# 0         总  计  2300000
# 1         汉  族  2198314
# 11        满  族    22627
# 8         壮  族    11281
# 15         土家族    10075

# %%
attr = data['民    族'][2:]
v1 = data['人口数'][2:]
bar = pye.Bar('中国人民解放军现役军人的民族构成')
bar.add('各民族人口', attr, v1, xaxis_rotate=70, xaxis_interval=0, 
        is_datazoom_show=True, mark_point=['max', 'min'])
bar
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="0bdfae8b89884a9d87677db02b71f800" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('0bdfae8b89884a9d87677db02b71f800'));
# var option =  {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "formatter": null,
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14,
#             "color": "#fff"
#         }
#     },
#     "legend": [
#         {
#             "top": "top",
#             "show": true,
#             "selectedMode": "multiple",
#             "left": "center",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             },
#             "data": [
#                 "\u5404\u6c11\u65cf\u4eba\u53e3"
#             ],
#             "orient": "horizontal"
#         }
#     ],
#     "yAxis": [
#         {
#             "nameLocation": "middle",
#             "show": true,
#             "name": "",
#             "position": null,
#             "max": null,
#             "inverse": false,
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "type": "value",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 },
#                 "formatter": "{value} ",
#                 "rotate": 0
#             },
#             "min": null
#         }
#     ],
#     "xAxis": [
#         {
#             "nameLocation": "middle",
#             "show": true,
#             "data": [
#                 "      \u8499\u53e4\u65cf",
#                 "      \u56de  \u65cf",
#                 "      \u85cf  \u65cf",
#                 "      \u7ef4\u543e\u5c14\u65cf",
#                 "      \u82d7  \u65cf",
#                 "      \u5f5d  \u65cf",
#                 "      \u58ee  \u65cf",
#                 "      \u5e03\u4f9d\u65cf",
#                 "      \u671d\u9c9c\u65cf",
#                 "      \u6ee1  \u65cf",
#                 "      \u4f97  \u65cf",
#                 "      \u7476  \u65cf",
#                 "      \u767d  \u65cf",
#                 "      \u571f\u5bb6\u65cf",
#                 "      \u54c8\u5c3c\u65cf",
#                 "      \u54c8\u8428\u514b\u65cf",
#                 "      \u50a3  \u65cf",
#                 "      \u9ece  \u65cf",
#                 "      \u5088\u50f3\u65cf",
#                 "      \u4f64  \u65cf",
#                 "      \u7572  \u65cf",
#                 "      \u9ad8\u5c71\u65cf",
#                 "      \u62c9\u795c\u65cf",
#                 "      \u6c34  \u65cf",
#                 "      \u4e1c\u4e61\u65cf",
#                 "      \u7eb3\u897f\u65cf",
#                 "      \u666f\u9887\u65cf",
#                 "      \u67ef\u5c14\u514b\u5b5c\u65cf",
#                 "      \u571f  \u65cf",
#                 "      \u8fbe\u65a1\u5c14\u65cf",
#                 "      \u4eeb\u4f6c\u65cf",
#                 "      \u7f8c\u65cf",
#                 "      \u5e03\u6717\u65cf",
#                 "      \u6492\u62c9\u65cf",
#                 "      \u6bdb\u5357\u65cf",
#                 "      \u4ee1\u4f6c\u65cf",
#                 "      \u9521\u4f2f\u65cf",
#                 "      \u963f\u660c\u65cf",
#                 "      \u666e\u7c73\u65cf",
#                 "      \u5854\u5409\u514b\u65cf",
#                 "      \u6012  \u65cf",
#                 "      \u4e4c\u5b5c\u522b\u514b\u65cf",
#                 "      \u4fc4\u7f57\u65af\u65cf",
#                 "      \u9102\u6e29\u514b\u65cf",
#                 "      \u5fb7\u6602\u65cf",
#                 "      \u4fdd\u5b89\u65cf",
#                 "      \u88d5\u56fa\u65cf",
#                 "      \u4eac  \u65cf",
#                 "      \u5854\u5854\u5c14\u65cf",
#                 "      \u72ec\u9f99\u65cf",
#                 "      \u9102\u4f26\u6625\u65cf",
#                 "      \u8d6b\u54f2\u65cf",
#                 "      \u95e8\u5df4\u65cf",
#                 "      \u73de\u5df4\u65cf",
#                 "      \u57fa\u8bfa\u65cf"
#             ],
#             "name": "",
#             "position": null,
#             "max": null,
#             "inverse": false,
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "type": "category",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 },
#                 "rotate": 70
#             },
#             "min": null
#         }
#     ],
#     "toolbox": {
#         "top": "center",
#         "show": true,
#         "feature": {
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             }
#         },
#         "orient": "vertical",
#         "left": "95%"
#     },
#     "series_id": 5725897,
#     "title": [
#         {
#             "top": "auto",
#             "text": "\u4e2d\u56fd\u4eba\u6c11\u89e3\u653e\u519b\u73b0\u5f79\u519b\u4eba\u7684\u6c11\u65cf\u6784\u6210",
#             "subtext": "",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#000"
#             },
#             "subtextStyle": {
#                 "fontSize": 12,
#                 "color": "#aaa"
#             },
#             "left": "auto"
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "yAxisIndex": null,
#             "start": 50,
#             "xAxisIndex": null,
#             "type": "slider",
#             "orient": "horizontal",
#             "end": 100
#         }
#     ],
#     "series": [
#         {
#             "barCategoryGap": "20%",
#             "stack": "",
#             "seriesId": 5725897,
#             "data": [
#                 8939.0,
#                 9859.0,
#                 4300.0,
#                 2048.0,
#                 6803.0,
#                 7059.0,
#                 11281.0,
#                 1791.0,
#                 1250.0,
#                 22627.0,
#                 2892.0,
#                 2108.0,
#                 2645.0,
#                 10075.0,
#                 831.0,
#                 424.0,
#                 594.0,
#                 1010.0,
#                 287.0,
#                 157.0,
#                 663.0,
#                 6.0,
#                 135.0,
#                 199.0,
#                 51.0,
#                 475.0,
#                 91.0,
#                 48.0,
#                 285.0,
#                 260.0,
#                 243.0,
#                 505.0,
#                 53.0,
#                 26.0,
#                 66.0,
#                 632.0,
#                 538.0,
#                 28.0,
#                 80.0,
#                 6.0,
#                 15.0,
#                 13.0,
#                 23.0,
#                 85.0,
#                 1.0,
#                 3.0,
#                 35.0,
#                 37.0,
#                 6.0,
#                 3.0,
#                 30.0,

# %% [markdown]
# # 现役解放军人民族分布
# - 上图数据不包括汉族数据。
# - 人数最多的是满族，最少的是德昂族。（内心os:好多民族没听过啊）

# %%
attr = list(data_1['民    族'][1:10])
attr.append('其他民族')
v1 = list(data_1['人口数'][1:10])
v1.append(data_1['人口数'][:1] - sum(v1))
pie = pye.Pie('各族族现役军人占比')
pie.add('', attr, v1, radius=[40, 75], label_text_color=None,
        is_label_show=True, legend_orient='vertical', legend_pos='right')
pie
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="090602b389b245df850f69c776a29a7e" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('090602b389b245df850f69c776a29a7e'));
# var option =  {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "formatter": null,
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14,
#             "color": "#fff"
#         }
#     },
#     "legend": [
#         {
#             "top": "top",
#             "show": true,
#             "selectedMode": "multiple",
#             "left": "right",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             },
#             "data": [
#                 "      \u6c49  \u65cf",
#                 "      \u6ee1  \u65cf",
#                 "      \u58ee  \u65cf",
#                 "      \u571f\u5bb6\u65cf",
#                 "      \u56de  \u65cf",
#                 "      \u8499\u53e4\u65cf",
#                 "      \u5f5d  \u65cf",
#                 "      \u82d7  \u65cf",
#                 "      \u85cf  \u65cf",
#                 "\u5176\u4ed6\u6c11\u65cf"
#             ],
#             "orient": "vertical"
#         }
#     ],
#     "toolbox": {
#         "top": "center",
#         "show": true,
#         "feature": {
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             }
#         },
#         "orient": "vertical",
#         "left": "95%"
#     },
#     "series_id": 6567349,
#     "title": [
#         {
#             "top": "auto",
#             "text": "\u6c49\u65cf\u73b0\u5f79\u519b\u4eba\u5360\u6bd4",
#             "subtext": "",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#000"
#             },
#             "subtextStyle": {
#                 "fontSize": 12,
#                 "color": "#aaa"
#             },
#             "left": "auto"
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     }
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "formatter": "{b}: {d}%",
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": null
#                     }
#                 }
#             },
#             "seriesId": 6567349,
#             "data": [
#                 {
#                     "value": 2198314,
#                     "name": "      \u6c49  \u65cf"
#                 },
#                 {
#                     "value": 22627,
#                     "name": "      \u6ee1  \u65cf"
#                 },
#                 {
#                     "value": 11281,
#                     "name": "      \u58ee  \u65cf"
#                 },
#                 {
#                     "value": 10075,
#                     "name": "      \u571f\u5bb6\u65cf"
#                 },
#                 {
#                     "value": 9859,
#                     "name": "      \u56de  \u65cf"
#                 },
#                 {
#                     "value": 8939,
#                     "name": "      \u8499\u53e4\u65cf"
#                 },
#                 {
#                     "value": 7059,
#                     "name": "      \u5f5d  \u65cf"
#                 },
#                 {
#                     "value": 6803,
#                     "name": "      \u82d7  \u65cf"
#                 },
#                 {
#                     "value": 4300,
#                     "name": "      \u85cf  \u65cf"
#                 },
#                 {
#                     "value": [
#                         20743.0
#                     ],
#                     "name": "\u5176\u4ed6\u6c11\u65cf"
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "type": "pie",
#             "name": "",
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": null
#         }
#     ]
# };
# myChart.setOption(option);
#
#     });
# </script>

# %% [markdown]
# # 各族族现役军人占比
# - 汉族占绝对的比例，毕竟汉族人口基数大
# - 为人民子弟兵点赞
