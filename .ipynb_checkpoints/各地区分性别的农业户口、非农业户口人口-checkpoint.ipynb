# %%
import pandas as pd
import numpy as np
import pyecharts as pye

# %%
data = pd.read_excel(r'data/1-2  各地区分性别的农业户口、非农业户口人口.xls')
data.head(5)
# Out:
#                合计         男         女  农业户口人口小计   农业户口人口男   农业户口人口女  \
# 全    国  126021054  64100818  61920236  90756710  46107686  44649024
# 北    京    1837491    935256    902235    678116    359671    318445
# 天    津    1121635    578549    543086    522307    278356    243951
# 河    北    6986390   3529230   3457160   5562298   2797950   2764348
# 山    西    3449025   1757581   1691444   2415087   1223126   1191961
#
#         非农业户口人口小计  非农业户口人口男  非农业户口人口女  非农业户口人口占总人口比重合计  非农业户口人口占总人口比重男  \
# 全    国   35264344  17993132  17271212            27.98           28.07
# 北    京    1159375    575585    583790            63.10           61.54
# 天    津     599328    300193    299135            53.43           51.89
# 河    北    1424092    731280    692812            20.38           20.72
# 山    西    1033938    534455    499483            29.98           30.41
#
#         非农业户口人口占总人口比重女
# 全    国           27.89
# 北    京           64.70
# 天    津           55.08
# 河    北           20.04
# 山    西           29.53

# %%
attr = data.index[1:]
title = ['农业户口人口', '农业户口人口男', '农业户口人口女', '非农业户口人口', '非农业户口男', '非农业人口女']
v1 = [data['农业户口人口小计'][1:], data['农业户口人口男'][1:], data['农业户口人口女'][1:], data['非农业户口人口小计'][1:], data['非农业户口人口男'][1:], data['非农业户口人口女'][1:]]
v1 = [round(a/1000000, 2) for a in v1]
bar = pye.Bar()
bar.add(title[0], attr, v1[0], xaxis_rotate=70, xaxis_interval=0, is_stack=True)
bar.add(title[3], attr, v1[3], xaxis_rotate=70, xaxis_interval=0, is_stack=True)
bar_1 = pye.Bar()
bar_1.add(title[1], attr, v1[1], xaxis_rotate=70, xaxis_interval=0, is_stack=True)
bar_1.add(title[2], attr, v1[2], xaxis_rotate=70, xaxis_interval=0, is_stack=True)
bar_2 = pye.Bar()
bar_2.add(title[4], attr, v1[4], xaxis_rotate=70, xaxis_interval=0, is_stack=True)
bar_2.add(title[5], attr, v1[5], xaxis_rotate=70, xaxis_interval=0, is_stack=True)
page = pye.Page()
page.add(bar)
page.add(bar_1)
page.add(bar_2)
page
# Out:
# [<pyecharts.charts.bar.Bar at 0x2f69b74de80>,
#  <pyecharts.charts.bar.Bar at 0x2f6972ac048>,
#  <pyecharts.charts.bar.Bar at 0x2f699b77f98>]

# %%
attr = data.index
title = ['非农业户口人口占总人口比重', '非农业户口人口占总人口比重男', '非农业户口人口占总人口比重女']
v1 = [data['非农业户口人口占总人口比重合计'], data['非农业户口人口占总人口比重男'], data['非农业户口人口占总人口比重女']]
line = pye.Line()
for i,j in zip(title, v1):
    line.add(i, attr, j, xaxis_rotate=70, xaxis_interval=0, mark_point=['max', 'min'], yaxis_formatter="%")
line
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="c1c8498834664acb87901b9b64d753e6" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('c1c8498834664acb87901b9b64d753e6'));
# var option =  {
#     "xAxis": [
#         {
#             "max": null,
#             "show": true,
#             "min": null,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "rotate": 70,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 },
#                 "interval": 0
#             },
#             "nameLocation": "middle",
#             "type": "category",
#             "inverse": false,
#             "position": null,
#             "data": [
#                 "\u5168    \u56fd",
#                 "\u5317    \u4eac",
#                 "\u5929    \u6d25",
#                 "\u6cb3    \u5317",
#                 "\u5c71    \u897f",
#                 "\u5185 \u8499 \u53e4",
#                 "\u8fbd    \u5b81",
#                 "\u5409    \u6797",
#                 "\u9ed1 \u9f99 \u6c5f",
#                 "\u4e0a    \u6d77",
#                 "\u6c5f    \u82cf",
#                 "\u6d59    \u6c5f",
#                 "\u5b89    \u5fbd",
#                 "\u798f    \u5efa",
#                 "\u6c5f    \u897f",
#                 "\u5c71    \u4e1c",
#                 "\u6cb3    \u5357",
#                 "\u6e56    \u5317",
#                 "\u6e56    \u5357",
#                 "\u5e7f    \u4e1c",
#                 "\u5e7f    \u897f",
#                 "\u6d77    \u5357",
#                 "\u91cd    \u5e86",
#                 "\u56db    \u5ddd",
#                 "\u8d35    \u5dde",
#                 "\u4e91    \u5357",
#                 "\u897f    \u85cf",
#                 "\u9655    \u897f",
#                 "\u7518    \u8083",
#                 "\u9752    \u6d77",
#                 "\u5b81    \u590f",
#                 "\u65b0    \u7586"
#             ],
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "boundaryGap": true,
#             "name": "",
#             "nameGap": 25
#         }
#     ],
#     "yAxis": [
#         {
#             "max": null,
#             "show": true,
#             "min": null,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "rotate": 0,
#                 "formatter": "{value} %",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 },
#                 "interval": "auto"
#             },
#             "nameLocation": "middle",
#             "type": "value",
#             "inverse": false,
#             "position": null,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "boundaryGap": true,
#             "name": "",
#             "nameGap": 25
#         }
#     ],
#     "series_id": 21904,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             }
#         },
#         "top": "center",
#         "orient": "vertical"
#     },
#     "legend": [
#         {
#             "show": true,
#             "selectedMode": "multiple",
#             "data": [
#                 "\u975e\u519c\u4e1a\u6237\u53e3\u4eba\u53e3\u5360\u603b\u4eba\u53e3\u6bd4\u91cd",
#                 "\u975e\u519c\u4e1a\u6237\u53e3\u4eba\u53e3\u5360\u603b\u4eba\u53e3\u6bd4\u91cd\u7537",
#                 "\u975e\u519c\u4e1a\u6237\u53e3\u4eba\u53e3\u5360\u603b\u4eba\u53e3\u6bd4\u91cd\u5973"
#             ],
#             "top": "top",
#             "left": "center",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "formatter": null,
#         "textStyle": {
#             "fontSize": 14,
#             "color": "#fff"
#         },
#         "triggerOn": "mousemove|click"
#     },
#     "backgroundColor": "#fff",
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12,
#                 "color": "#aaa"
#             },
#             "top": "auto",
#             "text": "",
#             "left": "auto",
#             "subtext": "",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#000"
#             }
#         }
#     ],
#     "series": [
#         {
#             "data": [
#                 27.98,
#                 63.1,
#                 53.43,
#                 20.38,
#                 29.98,
#                 37.32,
#                 50.31,
#                 44.23,
#                 48.69,
#                 62.37,
#                 32.59,
#                 24.67,
#                 23.34,
#                 21.75,
#                 24.87,
#                 22.04,
#                 18.84,
#                 29.41,
#                 22.0,
#                 27.42,
#                 19.04,
#                 33.84,
#                 33.8,
#                 24.47,
#                 17.19,
#                 15.86,
#                 14.41,
#                 24.04,
#                 23.26,
#                 26.8,
#                 35.12,
#                 39.19
#             ],
#             "type": "line",
#             "smooth": false,
#             "showSymbol": true,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "formatter": null,
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "type": "max",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "valueDim": null,
#                         "name": "Maximum"
#                     },
#                     {
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "type": "min",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "valueDim": null,
#                         "name": "Minimum"
#                     }
#                 ]
#             },
#             "step": false,
#             "areaStyle": {},
